# %% [markdown]
# #### Data Types

# %%
## integer ex

age=25
type(age)
# Out:
# int

# %%
## floating point DT

height=5.12
print(height)
print(type(height))
# Out:
# 5.12
# <class 'float'>

# %%
## string

name="Anshu"
print(name)
print(type(name))
# Out:
# Anshu
# <class 'str'>

# %%
## boolean DT

type(False)
# Out:
# bool

# %%
is_true=True
type(is_true)
# Out:
# bool

# %%
bool()
# Out:
# False

# %%
a=10
b=10

a==b    ##True
type(a==b)
# Out:
# bool

# %%
## common errors

##res = "Hello" + 25    ##error
##print(res)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 3
#       1 ## common errors
# ----> 3 res = "Hello" + 25
#       4 print(res)
#
# TypeError: can only concatenate str (not "int") to str

# %%
res = "Hello" + str(25)
print(res)
# Out:
# Hello25
